# %%
from os.path import join

english_yomi_paths = []

for sample in range(1,45):

    english_yomi_paths.append(join("..","jk",f"E{sample:02}.wav"))

print(english_yomi_paths)
# Out:
# ['../jk/E01.wav', '../jk/E02.wav', '../jk/E03.wav', '../jk/E04.wav', '../jk/E05.wav', '../jk/E06.wav', '../jk/E07.wav', '../jk/E08.wav', '../jk/E09.wav', '../jk/E10.wav', '../jk/E11.wav', '../jk/E12.wav', '../jk/E13.wav', '../jk/E14.wav', '../jk/E15.wav', '../jk/E16.wav', '../jk/E17.wav', '../jk/E18.wav', '../jk/E19.wav', '../jk/E20.wav', '../jk/E21.wav', '../jk/E22.wav', '../jk/E23.wav', '../jk/E24.wav', '../jk/E25.wav', '../jk/E26.wav', '../jk/E27.wav', '../jk/E28.wav', '../jk/E29.wav', '../jk/E30.wav', '../jk/E31.wav', '../jk/E32.wav', '../jk/E33.wav', '../jk/E34.wav', '../jk/E35.wav', '../jk/E36.wav', '../jk/E37.wav', '../jk/E38.wav', '../jk/E39.wav', '../jk/E40.wav', '../jk/E41.wav', '../jk/E42.wav', '../jk/E43.wav', '../jk/E44.wav']

# %%
japanese_yomi_paths = []

for sample in range(1,45):

    japanese_yomi_paths.append(join("..","jk",f"J{sample:02}.wav"))

print(japanese_yomi_paths)
# Out:
# ['../jk/J01.wav', '../jk/J02.wav', '../jk/J03.wav', '../jk/J04.wav', '../jk/J05.wav', '../jk/J06.wav', '../jk/J07.wav', '../jk/J08.wav', '../jk/J09.wav', '../jk/J10.wav', '../jk/J11.wav', '../jk/J12.wav', '../jk/J13.wav', '../jk/J14.wav', '../jk/J15.wav', '../jk/J16.wav', '../jk/J17.wav', '../jk/J18.wav', '../jk/J19.wav', '../jk/J20.wav', '../jk/J21.wav', '../jk/J22.wav', '../jk/J23.wav', '../jk/J24.wav', '../jk/J25.wav', '../jk/J26.wav', '../jk/J27.wav', '../jk/J28.wav', '../jk/J29.wav', '../jk/J30.wav', '../jk/J31.wav', '../jk/J32.wav', '../jk/J33.wav', '../jk/J34.wav', '../jk/J35.wav', '../jk/J36.wav', '../jk/J37.wav', '../jk/J38.wav', '../jk/J39.wav', '../jk/J40.wav', '../jk/J41.wav', '../jk/J42.wav', '../jk/J43.wav', '../jk/J44.wav']

# %%
from scipy.io.wavfile import read

english_yomi = []

for path in english_yomi_paths:

    eigo_sample,eigo_onsei = read(path)

    english_yomi.append(eigo_onsei)

print (english_yomi)
# Out:
# [array([ 38,  47,  71, ..., -14, -13, -17], dtype=int16), array([ 0, -1,  1, ..., -2, -3, -3], dtype=int16), array([-1, -1,  4, ...,  3,  2,  1], dtype=int16), array([2, 2, 3, ..., 6, 5, 2], dtype=int16), array([ 0, -3, -5, ..., -9, -8, -7], dtype=int16), array([4, 9, 9, ..., 6, 7, 6], dtype=int16), array([  5,   9,   8, ..., -18, -14, -13], dtype=int16), array([  7,   8,   9, ..., -15,  -9,  -8], dtype=int16), array([-4, -4, -8, ..., -5, -9, -7], dtype=int16), array([-20, -24, -26, ..., -14,  -8,  -4], dtype=int16), array([ 1,  0, -2, ...,  1,  1,  0], dtype=int16), array([2, 0, 1, ..., 7, 5, 0], dtype=int16), array([ 0, -1,  0, ..., 15, 16,  8], dtype=int16), array([-2, -2, -4, ...,  1,  0,  0], dtype=int16), array([ 0,  9, 48, ...,  0,  1, -3], dtype=int16), array([-8, -9, -5, ..., -1,  0, -3], dtype=int16), array([ -2,  -8, -18, ...,  -7,  -6,  -3], dtype=int16), array([ 0,  2,  4, ..., -2,  0, -1], dtype=int16), array([ 23,  74, 136, ...,  -8,  -4,  -2], dtype=int16), array([-1, -4, -1, ...,  7,  5,  4], dtype=int16), array([ 0,  2,  3, ..., -5, -2, -1], dtype=int16), array([0, 0, 0, ..., 2, 2, 0], dtype=int16), array([-1,  0,  1, ...,  3,  1,  0], dtype=int16), array([ 0, -2, -3, ..., -1, -2, -1], dtype=int16), array([-1,  1, 13, ..., -9, -4,  0], dtype=int16), array([ 0,  0, -3, ...,  0, -3, -1], dtype=int16), array([ 0, -2,  0, ...,  1,  2,  0], dtype=int16), array([ 1,  1,  0, ...,  1, -2, -2], dtype=int16), array([11, 46, 68, ...,  2,  4,  4], dtype=int16), array([  2,  14,  13, ..., -19, -19,  -9], dtype=int16), array([  0,   0,  -2, ..., -21, -15,  -3], dtype=int16), array([ 1,  3,  0, ..., -2,  0,  0], dtype=int16), array([ 1,  1,  1, ..., -4, -2, -2], dtype=int16), array([-1, -1,  3, ...,  1,  2, -1], dtype=int16), array([ 0,  0, -1, ...,  0,  2,  1], dtype=int16), array([ 0,  3,  8, ..., -2, -3, -3], dtype=int16), array([-2, -2,  4, ...,  1,  3,  0], dtype=int16), array([ 0,  0,  0, ..., -9, -7, -1], dtype=int16), array([  0,  -2,  -1, ..., -13,  -8,  -7], dtype=int16), array([0, 0, 2, ..., 8, 5, 2], dtype=int16), array([ 0,  0,  1, ..., -6, -1,  0], dtype=int16), array([ 0,  0, -1, ..., -3, -5, -2], dtype=int16), array([ 0,  1,  0, ...,  5, 13, 11], dtype=int16), array([-3, -3, -3, ..., 33, 29, 31], dtype=int16)]

# %%
japanese_yomi = []

for path in japanese_yomi_paths:

    nihongo_sample,nihongo_onsei = read(path)

    japanese_yomi.append(nihongo_onsei)

print (japanese_yomi)
# Out:
# [array([  0,  -5, -11, ...,  -2,  -3,  -2], dtype=int16), array([-1, -1,  0, ..., -1, -1,  0], dtype=int16), array([0, 2, 5, ..., 0, 0, 0], dtype=int16), array([1, 1, 0, ..., 2, 0, 0], dtype=int16), array([2, 3, 0, ..., 0, 1, 2], dtype=int16), array([ 0,  0, -1, ..., -1, -2, -1], dtype=int16), array([0, 0, 0, ..., 1, 0, 0], dtype=int16), array([0, 0, 0, ..., 7, 6, 2], dtype=int16), array([ 2,  4,  3, ...,  2, -1,  0], dtype=int16), array([0, 1, 1, ..., 4, 4, 4], dtype=int16), array([ 0,  0,  0, ...,  0,  0, -1], dtype=int16), array([ 0,  0,  0, ..., -1, -3, -3], dtype=int16), array([0, 0, 0, ..., 0, 0, 0], dtype=int16), array([ 0, -1, -1, ..., -1, -5, -4], dtype=int16), array([ 0,  0,  1, ...,  1, -1, -1], dtype=int16), array([0, 0, 0, ..., 0, 0, 1], dtype=int16), array([ 0,  0,  0, ..., -1, -1, -1], dtype=int16), array([0, 1, 2, ..., 0, 0, 0], dtype=int16), array([0, 0, 0, ..., 2, 1, 0], dtype=int16), array([ 0,  0,  0, ..., -1,  0,  0], dtype=int16), array([1, 8, 5, ..., 1, 2, 1], dtype=int16), array([0, 0, 0, ..., 2, 4, 0], dtype=int16), array([ 0,  0, -1, ...,  0,  0,  0], dtype=int16), array([0, 0, 1, ..., 0, 0, 0], dtype=int16), array([0, 0, 2, ..., 0, 1, 0], dtype=int16), array([  0,   0,   0, ...,  -8, -16, -29], dtype=int16), array([ 0,  0,  0, ...,  0, -3, -5], dtype=int16), array([ 0,  0,  1, ...,  0, -2, -7], dtype=int16), array([ 1,  0,  0, ...,  2,  0, -5], dtype=int16), array([0, 0, 1, ..., 1, 4, 4], dtype=int16), array([0, 2, 3, ..., 3, 3, 0], dtype=int16), array([ 0,  1,  1, ..., -2, -1,  0], dtype=int16), array([0, 2, 4, ..., 2, 1, 1], dtype=int16), array([0, 2, 2, ..., 2, 2, 2], dtype=int16), array([1, 3, 3, ..., 2, 2, 1], dtype=int16), array([  4,  -4, -13, ...,   1,   0,   0], dtype=int16), array([0, 0, 0, ..., 5, 3, 0], dtype=int16), array([0, 1, 3, ..., 0, 1, 0], dtype=int16), array([0, 0, 1, ..., 0, 0, 0], dtype=int16), array([0, 0, 0, ..., 4, 3, 2], dtype=int16), array([ 5,  4,  4, ..., -1,  0,  1], dtype=int16), array([ 0,  1,  2, ..., -2, -3, -2], dtype=int16), array([ 0,  1,  2, ..., -2, -2,  0], dtype=int16), array([0, 0, 0, ..., 1, 1, 0], dtype=int16)]

# %%
import matplotlib.pyplot as plt
import numpy as np

graph_data = (english_yomi[10])

time_data = np.linspace(0,len(graph_data)/48000,len(graph_data))

plt.plot(time_data,graph_data)

# %%
spectrogram_data = plt.specgram(graph_data)

plt
# Out:
# <module 'matplotlib.pyplot' from '/Users/rkeclair/Documents/Projects/comb/procon2022_comp/venv/lib/python3.9/site-packages/matplotlib/pyplot.py'>

# %%
from maesyori import preprocess_input

neural_input_data = preprocess_input(graph_data)
plt.imshow(np.abs(neural_input_data), aspect="auto", origin="lower")
neural_input_data.shape
# Out:
# (128, 128)
